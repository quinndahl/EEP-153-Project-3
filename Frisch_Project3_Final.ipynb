# %% [markdown]
# # Team Frisch Project 3
#
# ### Background
#
# After doing research, we understand that Malawi suffers from extreme hunger, malnutrition, poverty, high disease rates, and is more susceptable to natural disasters. All of these are also exacerbated by present and future climate change. As a result, we are interested in understanding the the food demand for households in Malawi in order to investigate any profound results relative to their diets.
#
# We will first begin by installing all necessary packages to complete our deliverables.

# %%
# !pip install CFEDemands
# !pip install ConsumerDemands
# !pip install oauth2client
# !pip install eep153_tools
# !pip install dvc
# !pip install gnupg
# Out:
# Collecting CFEDemands
#   Using cached CFEDemands-0.4.1-py2.py3-none-any.whl (39 kB)
# Installing collected packages: CFEDemands
# Successfully installed CFEDemands-0.4.1
# Collecting ConsumerDemands
#   Using cached ConsumerDemands-0.3.dev0-py2.py3-none-any.whl (12 kB)
# Installing collected packages: ConsumerDemands
# Successfully installed ConsumerDemands-0.3.dev0
# Collecting oauth2client
#   Using cached oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# Requirement already satisfied: httplib2>=0.9.1 in /opt/conda/lib/python3.9/site-packages (from oauth2client) (0.20.4)
# Requirement already satisfied: six>=1.6.1 in /opt/conda/lib/python3.9/site-packages (from oauth2client) (1.16.0)
# Requirement already satisfied: rsa>=3.1.4 in /opt/conda/lib/python3.9/site-packages (from oauth2client) (4.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /opt/conda/lib/python3.9/site-packages (from oauth2client) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /opt/conda/lib/python3.9/site-packages (from oauth2client) (0.2.8)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2; python_version > "3.0" in /opt/conda/lib/python3.9/site-packages (from httplib2>=0.9.1->oauth2client) (3.0.7)
# Installing collected packages: oauth2client
# Successfully installed oauth2client-4.1.3
# Collecting eep153_tools
#   Using cached eep153_tools-0.11-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: eep153-tools
# Successfully installed eep153-tools-0.11
# Collecting dvc
#   Using cached dvc-2.10.1-py3-none-any.whl (400 kB)
# Collecting dpath<3,>=2.0.2
#   Using cached dpath-2.0.6-py3-none-any.whl (15 kB)
# Collecting flufl.lock>=5
#   Using cached flufl.lock-7.0-py3-none-any.whl (11 kB)
# Collecting shtab<2,>=1.3.4
#   Using cached shtab-1.5.3-py2.py3-none-any.whl (12 kB)
# Processing /home/jovyan/.cache/pip/wheels/4b/35/53/dfa4d3a4196794cb0a777a97c68dcf02b073d33de9c135d72a/configobj-5.0.6-py3-none-any.whl
# Collecting flatten-dict<1,>=0.4.1
#   Using cached flatten_dict-0.4.2-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: tabulate>=0.8.7 in /opt/conda/lib/python3.9/site-packages (from dvc) (0.8.9)
# Collecting aiohttp-retry>=2.4.5
#   Using cached aiohttp_retry-2.4.6-py3-none-any.whl (7.7 kB)
# Collecting funcy>=1.14
#   Using cached funcy-1.17-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /opt/conda/lib/python3.9/site-packages (from dvc) (3.10.0.2)
# Collecting diskcache>=5.2.1
#   Using cached diskcache-5.4.0-py3-none-any.whl (44 kB)
# Requirement already satisfied: fsspec[http]>=2021.10.1 in /opt/conda/lib/python3.9/site-packages (from dvc) (2022.2.0)
# Collecting shortuuid>=0.5.0
#   Using cached shortuuid-1.0.8-py3-none-any.whl (9.5 kB)
# Collecting dvc-render==0.0.4
#   Using cached dvc_render-0.0.4-py3-none-any.whl (14 kB)
# Processing /home/jovyan/.cache/pip/wheels/ee/1f/7c/610bdb7d5541b98d9743c5953e32681ef35dd54fadddd347e8/nanotime-0.5.2-py3-none-any.whl
# Requirement already satisfied: colorama>=0.3.9 in /opt/conda/lib/python3.9/site-packages (from dvc) (0.4.3)
# Collecting python-benedict>=0.24.2
#   Using cached python_benedict-0.25.0-py3-none-any.whl (40 kB)
# Processing /home/jovyan/.cache/pip/wheels/2e/5d/81/d6e52fec193180ffffef19b185ecf1d0a85d418808c20c09c9/pygtrie-2.4.2-py3-none-any.whl
# Requirement already satisfied: requests>=2.22.0 in /opt/conda/lib/python3.9/site-packages (from dvc) (2.26.0)
# Requirement already satisfied: distro>=1.3.0 in /opt/conda/lib/python3.9/site-packages (from dvc) (1.7.0)
# Collecting grandalf==0.6
#   Using cached grandalf-0.6-py3-none-any.whl (31 kB)
# Requirement already satisfied: ruamel.yaml>=0.17.11 in /opt/conda/lib/python3.9/site-packages (from dvc) (0.17.21)
# Requirement already satisfied: pydot>=1.2.4 in /opt/conda/lib/python3.9/site-packages (from dvc) (1.4.2)
# Requirement already satisfied: appdirs>=1.4.3 in /opt/conda/lib/python3.9/site-packages (from dvc) (1.4.4)
# Requirement already satisfied: pyparsing>=2.4.7 in /opt/conda/lib/python3.9/site-packages (from dvc) (3.0.7)
# Collecting tqdm<5,>=4.63.1
#   Using cached tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# Collecting dictdiffer>=0.8.1
#   Using cached dictdiffer-0.9.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.9/site-packages (from dvc) (5.9.0)
# Collecting toml>=0.10.1
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: networkx>=2.5 in /opt/conda/lib/python3.9/site-packages (from dvc) (2.6.3)
# Collecting pathspec<0.10.0,>=0.9.0
#   Using cached pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting zc.lockfile>=1.2.1
#   Using cached zc.lockfile-2.0-py2.py3-none-any.whl (9.7 kB)
# Collecting voluptuous>=0.11.7
#   Using cached voluptuous-0.13.1-py3-none-any.whl (29 kB)
# Collecting rich>=10.13.0
#   Using cached rich-12.2.0-py3-none-any.whl (229 kB)
# Requirement already satisfied: packaging>=19.0 in /opt/conda/lib/python3.9/site-packages (from dvc) (21.3)
# Collecting scmrepo==0.0.16
#   Using cached scmrepo-0.0.16-py3-none-any.whl (40 kB)
# Collecting atpublic>=2.3
#   Using cached atpublic-3.0.1-py3-none-any.whl (4.8 kB)
# Requirement already satisfied: six in /opt/conda/lib/python3.9/site-packages (from configobj>=5.0.6->dvc) (1.16.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.9/site-packages (from aiohttp-retry>=2.4.5->dvc) (3.8.1)
# Processing /home/jovyan/.cache/pip/wheels/64/82/49/87959d73da9a5aa15f04f3a2ee002f4530e3234c7c240f4943/mailchecker-4.1.14-py3-none-any.whl
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /opt/conda/lib/python3.9/site-packages (from python-benedict>=0.24.2->dvc) (6.0)
# Collecting ftfy<7.0.0,>=6.0.0
#   Using cached ftfy-6.1.1-py3-none-any.whl (53 kB)
# Collecting xmltodict<1.0.0,>=0.12.0
#   Using cached xmltodict-0.12.0-py2.py3-none-any.whl (9.2 kB)
# Collecting phonenumbers<9.0.0,>=8.12.0
#   Using cached phonenumbers-8.12.46-py2.py3-none-any.whl (2.6 MB)
# Collecting python-fsutil<1.0.0,>=0.6.0
#   Using cached python_fsutil-0.6.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /opt/conda/lib/python3.9/site-packages (from python-benedict>=0.24.2->dvc) (2.8.0)
# Collecting python-slugify<7.0.0,>=6.0.1
#   Using cached python_slugify-6.1.1-py2.py3-none-any.whl (9.1 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests>=2.22.0->dvc) (1.25.7)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /opt/conda/lib/python3.9/site-packages (from requests>=2.22.0->dvc) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests>=2.22.0->dvc) (2019.11.28)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /opt/conda/lib/python3.9/site-packages (from requests>=2.22.0->dvc) (2.8)
# Requirement already satisfied: future in /opt/conda/lib/python3.9/site-packages (from grandalf==0.6->dvc) (0.18.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6; platform_python_implementation == "CPython" and python_version < "3.11" in /opt/conda/lib/python3.9/site-packages (from ruamel.yaml>=0.17.11->dvc) (0.2.6)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from zc.lockfile>=1.2.1->dvc) (58.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /opt/conda/lib/python3.9/site-packages (from rich>=10.13.0->dvc) (2.11.2)
# Collecting commonmark<0.10.0,>=0.9.0
#   Using cached commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
# Collecting dulwich>=0.20.34
#   Using cached dulwich-0.20.35-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (550 kB)
# Collecting pygit2>=1.7.2
#   Using cached pygit2-1.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
# Collecting gitpython>3
#   Using cached GitPython-3.1.27-py3-none-any.whl (181 kB)
# Collecting asyncssh<3,>=2.7.1
#   Using cached asyncssh-2.10.0-py3-none-any.whl (335 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.4.5->dvc) (19.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.4.5->dvc) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.4.5->dvc) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.4.5->dvc) (6.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.4.5->dvc) (1.3.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.4.5->dvc) (1.7.2)
# Requirement already satisfied: wcwidth>=0.2.5 in /opt/conda/lib/python3.9/site-packages (from ftfy<7.0.0,>=6.0.0->python-benedict>=0.24.2->dvc) (0.2.5)
# Collecting text-unidecode>=1.3
#   Using cached text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: cffi>=1.9.1 in /opt/conda/lib/python3.9/site-packages (from pygit2>=1.7.2->scmrepo==0.0.16->dvc) (1.14.6)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# Requirement already satisfied: cryptography>=2.8 in /opt/conda/lib/python3.9/site-packages (from asyncssh<3,>=2.7.1->scmrepo==0.0.16->dvc) (3.4.8)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.9/site-packages (from cffi>=1.9.1->pygit2>=1.7.2->scmrepo==0.0.16->dvc) (2.20)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Installing collected packages: dpath, atpublic, flufl.lock, shtab, configobj, flatten-dict, aiohttp-retry, funcy, diskcache, shortuuid, dvc-render, nanotime, mailchecker, toml, ftfy, xmltodict, phonenumbers, python-fsutil, text-unidecode, python-slugify, python-benedict, pygtrie, grandalf, tqdm, dictdiffer, pathspec, zc.lockfile, voluptuous, commonmark, rich, dulwich, pygit2, smmap, gitdb, gitpython, asyncssh, scmrepo, dvc
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.62.1
#     Uninstalling tqdm-4.62.1:
#       Successfully uninstalled tqdm-4.62.1
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# pysal 2.5.0 requires urllib3>=1.26, but you'll have urllib3 1.25.7 which is incompatible.
# pyppeteer 1.0.2 requires certifi>=2021, but you'll have certifi 2019.11.28 which is incompatible.
# pyppeteer 1.0.2 requires urllib3<2.0.0,>=1.25.8, but you'll have urllib3 1.25.7 which is incompatible.
# allensdk 2.12.2 requires aiohttp==3.7.4, but you'll have aiohttp 3.8.1 which is incompatible.
# allensdk 2.12.2 requires h5py<3.0.0,>=2.8, but you'll have h5py 3.3.0 which is incompatible.
# allensdk 2.12.2 requires jinja2<2.12.0,>=2.7.3, but you'll have jinja2 3.1.1 which is incompatible.
# allensdk 2.12.2 requires matplotlib<3.4.3,>=1.4.3, but you'll have matplotlib 3.4.3 which is incompatible.
# allensdk 2.12.2 requires nest-asyncio==1.2.0, but you'll have nest-asyncio 1.5.4 which is incompatible.
# allensdk 2.12.2 requires numpy<1.19.0,>=1.15.4, but you'll have numpy 1.21.5 which is incompatible.
# allensdk 2.12.2 requires pandas<=0.25.3,>=0.25.1, but you'll have pandas 1.3.5 which is incompatible.
# allensdk 2.12.2 requires scikit-image<0.17.0,>=0.14.0, but you'll have scikit-image 0.18.3 which is incompatible.
# allensdk 2.12.2 requires xarray<0.16.0, but you'll have xarray 0.19.0 which is incompatible.
# Successfully installed aiohttp-retry-2.4.6 asyncssh-2.10.0 atpublic-3.0.1 commonmark-0.9.1 configobj-5.0.6 dictdiffer-0.9.0 diskcache-5.4.0 dpath-2.0.6 dulwich-0.20.35 dvc-2.10.1 dvc-render-0.0.4 flatten-dict-0.4.2 flufl.lock-7.0 ftfy-6.1.1 funcy-1.17 gitdb-4.0.9 gitpython-3.1.27 grandalf-0.6 mailchecker-4.1.14 nanotime-0.5.2 pathspec-0.9.0 phonenumbers-8.12.46 pygit2-1.9.1 pygtrie-2.4.2 python-benedict-0.25.0 python-fsutil-0.6.0 python-slugify-6.1.1 rich-12.2.0 scmrepo-0.0.16 shortuuid-1.0.8 shtab-1.5.3 smmap-5.0.0 text-unidecode-1.3 toml-0.10.2 tqdm-4.64.0 voluptuous-0.13.1 xmltodict-0.12.0 zc.lockfile-2.0
# Processing /home/jovyan/.cache/pip/wheels/20/7e/30/7d702acd6a1e89911301cd9dbf9cb9870ca80c0e64bc2cde23/gnupg-2.3.1-py3-none-any.whl
# Requirement already satisfied: psutil>=1.2.1 in /opt/conda/lib/python3.9/site-packages (from gnupg) (5.9.0)
# Installing collected packages: gnupg
# Successfully installed gnupg-2.3.1

# %% [markdown]
# ## Deliverbale [A] Choice of population with supporting expenditure data
#
# As previously mentioned, we have chosen households in Malawi as our population of interest. To get expenditure data, we are importing sheets from Malawi Integrated Household Survey (IHS) for the years 2004 and 2010.
#
# We begin this process by first defining our input file. Then we run the eep153_tools.sheets function provided in class to read the sheet.

# %%
InputFiles = {'Expenditures':('1-rP6IC2wm91nH94xApeLCXS7dslqlsTns9si57Hs1c0','Expenditures'),
              'malawi_consumption':('1c2rXKtnVawQ802xAh4qm5HDK9MiFTFlGZJjcgTooRVo','malawi_consumption'),
              'HH Characteristics':('1-rP6IC2wm91nH94xApeLCXS7dslqlsTns9si57Hs1c0','HH Characteristics'),
              'FCT':('1Uy4h4cB3_O6Ls3Pvk920ScTA1jaKdVb4TAkZ51n-8DA','05 NV_sum_57 (per 100g EP)')}

# %%
from eep153_tools.sheets import read_sheets
import numpy as np
import pandas as pd

def get_clean_sheet(key,sheet=None):

    dfs = read_sheets(key)

    if sheet is not None:
        df = dfs[sheet]
    else:
        df = dfs.values()[0]
        
    df.columns = [c.strip() for c in df.columns.tolist()]

    df = df.loc[:,~df.columns.duplicated(keep='first')]   

    df = df.drop([col for col in df.columns if col.startswith('Unnamed')], axis=1)

    df = df.loc[~df.index.duplicated(), :]

    return df

# %% [markdown]
# We can now extract the information for expenditures by reading in the input files- expenditures. We also set any 0 inputs to NaN for future ease in consolidating the information and creating visualizations. The expenditures is expressed in local currency; in this case that would be the Malawian kwacha.

# %%
x = get_clean_sheet(InputFiles['Expenditures'][0],
                    sheet=InputFiles['Expenditures'][1])

if 'm' not in x.columns:
    x['m'] = 1

x = x.set_index(['j','t','m'])
x.columns.name = 'i'

x = x.apply(lambda x: pd.to_numeric(x,errors='coerce'))
x = x.replace(0,np.nan)

x
# Out:
# Key available for students@eep153.iam.gserviceaccount.com.
# i                    Apple  Avocado  Banana  Bean, brown  Bean, white   Beef  \
# j            t    m
# 10101002025  2004 1    NaN     10.0     NaN          NaN          NaN  160.0
# 10101002051  2004 1    NaN      NaN     NaN          NaN          NaN    NaN
# 10101002072  2004 1    NaN      5.0     5.0          NaN          NaN    NaN
# 10101002079  2004 1    NaN     16.0    60.0          NaN          NaN   60.0
# 10101002095  2004 1    NaN      NaN     NaN          NaN          NaN    NaN
# ...                    ...      ...     ...          ...          ...    ...
# 315556140342 2010 1    NaN      NaN     NaN        160.0          NaN    NaN
# 315556140365 2010 1    NaN      NaN    50.0          NaN          NaN    NaN
# 315556140388 2010 1    NaN      NaN     NaN          NaN          NaN    NaN
# 315556140411 2010 1    NaN      NaN     NaN          NaN        225.0    NaN
# 315556140434 2010 1    NaN      NaN   100.0        170.0          NaN  500.0
#
# i                    Biscuits  Bottled water  Bottled/ canned beer  Bread  \
# j            t    m
# 10101002025  2004 1       NaN            NaN                   NaN    NaN
# 10101002051  2004 1       NaN            NaN                   NaN    NaN
# 10101002072  2004 1       NaN            NaN                   NaN    NaN
# 10101002079  2004 1       NaN            NaN                   NaN    NaN
# 10101002095  2004 1       NaN            NaN                   NaN    NaN
# ...                       ...            ...                   ...    ...
# 315556140342 2010 1       NaN            NaN                   NaN  260.0
# 315556140365 2010 1       NaN            NaN                   NaN    NaN
# 315556140388 2010 1       NaN            NaN                   NaN    NaN
# 315556140411 2010 1       NaN            NaN                   NaN    NaN
# 315556140434 2010 1       NaN            NaN                   NaN  130.0
#
# i                    ...  Tomato  Tomato sauce (bottle)  \
# j            t    m  ...
# 10101002025  2004 1  ...     5.0                    NaN
# 10101002051  2004 1  ...     5.0                    NaN
# 10101002072  2004 1  ...     NaN                    NaN
# 10101002079  2004 1  ...    10.0                    NaN
# 10101002095  2004 1  ...     NaN                    NaN
# ...                  ...     ...                    ...
# 315556140342 2010 1  ...   150.0                    NaN
# 315556140365 2010 1  ...    80.0                    NaN
# 315556140388 2010 1  ...    40.0                    NaN
# 315556140411 2010 1  ...   100.0                    NaN
# 315556140434 2010 1  ...   100.0                    NaN
#
# i                    Traditional beer (masase)  Wheat flour  \
# j            t    m
# 10101002025  2004 1                        NaN          NaN
# 10101002051  2004 1                        NaN          NaN
# 10101002072  2004 1                        NaN          NaN
# 10101002079  2004 1                        NaN          NaN
# 10101002095  2004 1                        NaN          NaN
# ...                                        ...          ...
# 315556140342 2010 1                        NaN          NaN
# 315556140365 2010 1                        NaN          NaN
# 315556140388 2010 1                        NaN          NaN
# 315556140411 2010 1                        NaN          NaN
# 315556140434 2010 1                        NaN          NaN
#
# i                    White sweet potato  Wild fruit (masau, mlambe, etc.)  \
# j            t    m
# 10101002025  2004 1                 NaN                               NaN
# 10101002051  2004 1                 NaN                               NaN
# 10101002072  2004 1                 NaN                               NaN
# 10101002079  2004 1                 NaN                               NaN
# 10101002095  2004 1                 NaN                               NaN
# ...                                 ...                               ...
# 315556140342 2010 1               200.0                               NaN
# 315556140365 2010 1               100.0                               NaN
# 315556140388 2010 1                50.0                               NaN
# 315556140411 2010 1               200.0                               NaN
# 315556140434 2010 1                 NaN                               NaN
#
# i                    Wine or commercial liquor  \
# j            t    m
# 10101002025  2004 1                        NaN
# 10101002051  2004 1                        NaN
# 10101002072  2004 1                        NaN
# 10101002079  2004 1                        NaN
# 10101002095  2004 1                        NaN
# ...                                        ...
# 315556140342 2010 1                        NaN
# 315556140365 2010 1                        NaN
# 315556140388 2010 1                        NaN
# 315556140411 2010 1                        NaN
# 315556140434 2010 1                        NaN
#
# i                    Yeast, baking powder, bicarbonate of soda  Yoghurt  nan
# j            t    m
# 10101002025  2004 1                                        4.0      NaN  NaN
# 10101002051  2004 1                                        NaN      NaN  NaN
# 10101002072  2004 1                                        3.0      NaN  NaN
# 10101002079  2004 1                                        2.0      NaN  NaN
# 10101002095  2004 1                                        3.0      NaN  NaN
# ...                                                        ...      ...  ...
# 315556140342 2010 1                                        NaN      NaN  NaN
# 315556140365 2010 1                                        NaN      NaN  NaN
# 315556140388 2010 1                                        NaN      NaN  NaN
# 315556140411 2010 1                                        NaN      NaN  NaN
# 315556140434 2010 1                                        NaN      NaN  NaN
#
# [23551 rows x 129 columns]

# %% [markdown]
# Now that we have the information for expenditures in the given years, we will follow the same process to extract information from our input filez relative to households in Malawi. This data is very detailed and gives us household characteristics including the composition of households by age and sex.

# %%
# Get HH characteristics...
z = get_clean_sheet(InputFiles['HH Characteristics'][0],
                    sheet=InputFiles['HH Characteristics'][1])

if 'm' not in z.columns:
    z['m'] = 1

z = z.set_index(['j','t','m'])
z.columns.name = 'k'

z = z.apply(lambda x: pd.to_numeric(x,errors='coerce'))

z
# Out:
# Key available for students@eep153.iam.gserviceaccount.com.
# k                    M 0-3  M 4-8  M 9-13  M 14-18  M 19-30  M 31-50  M 51+  \
# j            t    m
# 10101002025  2004 1      1      0       1        1        0        1      0
# 10101002051  2004 1      0      0       0        0        1        0      0
# 10101002072  2004 1      1      1       0        1        0        1      0
# 10101002079  2004 1      0      1       0        0        0        1      0
# 10101002095  2004 1      0      0       2        0        1        0      0
# ...                    ...    ...     ...      ...      ...      ...    ...
# 315556140342 2010 1      1      0       0        0        1        0      0
# 315556140365 2010 1      0      0       0        0        0        1      0
# 315556140388 2010 1      0      0       0        0        1        0      0
# 315556140411 2010 1      1      0       0        0        2        0      0
# 315556140434 2010 1      0      0       0        1        0        1      0
#
# k                    F 0-3  F 4-8  F 9-13  F 14-18  F 19-30  F 31-50  F 51+
# j            t    m
# 10101002025  2004 1      1      1       0        0        0        1      0
# 10101002051  2004 1      1      0       0        1        0        0      0
# 10101002072  2004 1      1      0       0        0        1        0      0
# 10101002079  2004 1      2      1       0        0        0        1      0
# 10101002095  2004 1      0      2       0        0        1        0      0
# ...                    ...    ...     ...      ...      ...      ...    ...
# 315556140342 2010 1      0      0       0        0        1        0      0
# 315556140365 2010 1      0      0       0        0        0        1      0
# 315556140388 2010 1      0      0       0        1        0        0      0
# 315556140411 2010 1      1      0       0        0        1        0      0
# 315556140434 2010 1      0      0       2        0        2        1      0
#
# [23551 rows x 14 columns]

# %% [markdown]
# ## Deliverable [A] Estimate Demand System
#
# Now that we have expenditure and household characterstics, we can import consumption from the same data source and estimate the demand system.
#
# This entails a similar process as before- getting the consumption from the input files.

# %%
q = get_clean_sheet(InputFiles['malawi_consumption'][0],
                    sheet=InputFiles['malawi_consumption'][1])

if 'm' not in q.columns:
    q['m'] = 1

q = q.set_index(['j','t','m','u'])
q.columns.name = 'i'

q = q.apply(lambda x: pd.to_numeric(x,errors='coerce'))
q = q.replace(0,np.nan)

q
# Out:
# Key available for students@eep153.iam.gserviceaccount.com.
# i                              Apple  Avocado  Banana  Bean, brown  \
# j           t    m u
# 10101002025 2004 1 Gram          NaN      NaN     NaN          NaN
#                    Kg            NaN      NaN     NaN          NaN
#                    Millilitre    NaN      NaN     NaN          NaN
#                    Piece         NaN      2.0     NaN          NaN
# 10101002051 2004 1 Gram          NaN      NaN     NaN          NaN
# ...                              ...      ...     ...          ...
# 31202086364 2004 1 Kg            NaN      NaN     NaN          NaN
#                    Millilitre    NaN      NaN     NaN          NaN
#                    Piece         NaN      NaN     NaN          NaN
# 31202086374 2004 1 Kg            NaN      NaN     NaN          NaN
#                    Piece         NaN      NaN     NaN          NaN
#
# i                              Bean, white  Beef  Biscuits  Bottled water  \
# j           t    m u
# 10101002025 2004 1 Gram                NaN   NaN       NaN            NaN
#                    Kg                  NaN   2.0       NaN            NaN
#                    Millilitre          NaN   NaN       NaN            NaN
#                    Piece               NaN   NaN       NaN            NaN
# 10101002051 2004 1 Gram                NaN   NaN       NaN            NaN
# ...                                    ...   ...       ...            ...
# 31202086364 2004 1 Kg                  NaN   NaN       NaN            NaN
#                    Millilitre          NaN   NaN       NaN            NaN
#                    Piece               NaN   NaN       NaN            NaN
# 31202086374 2004 1 Kg                  NaN   NaN       NaN            NaN
#                    Piece               NaN   NaN       NaN            NaN
#
# i                              Bottled/ canned beer  Bread  ...  Tomato  \
# j           t    m u                                        ...
# 10101002025 2004 1 Gram                         NaN    NaN  ...     NaN
#                    Kg                           NaN    NaN  ...     NaN
#                    Millilitre                   NaN    NaN  ...     NaN
#                    Piece                        NaN    NaN  ...     5.0
# 10101002051 2004 1 Gram                         NaN    NaN  ...     NaN
# ...                                             ...    ...  ...     ...
# 31202086364 2004 1 Kg                           NaN    NaN  ...     NaN
#                    Millilitre                   NaN    NaN  ...     NaN
#                    Piece                        NaN    NaN  ...    15.0
# 31202086374 2004 1 Kg                           NaN    NaN  ...     NaN
#                    Piece                        NaN    NaN  ...     7.0
#
# i                              Tomato sauce (bottle)  \
# j           t    m u
# 10101002025 2004 1 Gram                          NaN
#                    Kg                            NaN
#                    Millilitre                    NaN
#                    Piece                         NaN
# 10101002051 2004 1 Gram                          NaN
# ...                                              ...
# 31202086364 2004 1 Kg                            NaN
#                    Millilitre                    NaN
#                    Piece                         NaN
# 31202086374 2004 1 Kg                            NaN
#                    Piece                         NaN
#
# i                              Traditional beer (masase)  Wheat flour  \
# j           t    m u
# 10101002025 2004 1 Gram                              NaN          NaN
#                    Kg                                NaN          NaN
#                    Millilitre                        NaN          NaN
#                    Piece                             NaN          NaN
# 10101002051 2004 1 Gram                              NaN          NaN
# ...                                                  ...          ...
# 31202086364 2004 1 Kg                                NaN          NaN
#                    Millilitre                        NaN          NaN
#                    Piece                             NaN          NaN
# 31202086374 2004 1 Kg                                NaN          NaN
#                    Piece                             NaN          NaN
#
# i                              White sweet potato  \
# j           t    m u
# 10101002025 2004 1 Gram                       NaN
#                    Kg                         NaN
#                    Millilitre                 NaN
#                    Piece                      NaN
# 10101002051 2004 1 Gram                       NaN
# ...                                           ...
# 31202086364 2004 1 Kg                         NaN
#                    Millilitre                 NaN
#                    Piece                     15.0
# 31202086374 2004 1 Kg                         NaN
#                    Piece                      NaN
#
# i                              Wild fruit (masau, mlambe, etc.)  \
# j           t    m u
# 10101002025 2004 1 Gram                                     NaN
#                    Kg                                       NaN
#                    Millilitre                               NaN
#                    Piece                                    NaN
# 10101002051 2004 1 Gram                                     NaN
# ...                                                         ...
# 31202086364 2004 1 Kg                                       NaN
#                    Millilitre                               NaN
#                    Piece                                    NaN
# 31202086374 2004 1 Kg                                       NaN
#                    Piece                                    NaN
#
# i                              Wine or commercial liquor  \
# j           t    m u
# 10101002025 2004 1 Gram                              NaN
#                    Kg                                NaN
#                    Millilitre                        NaN
#                    Piece                             NaN
# 10101002051 2004 1 Gram                              NaN
# ...                                                  ...
# 31202086364 2004 1 Kg                                NaN
#                    Millilitre                        NaN
#                    Piece                             NaN
# 31202086374 2004 1 Kg                                NaN
#                    Piece                             NaN
#
# i                              Yeast, baking powder, bicarbonate of soda  \
# j           t    m u
# 10101002025 2004 1 Gram                                              NaN
#                    Kg                                                NaN
#                    Millilitre                                        NaN
#                    Piece                                             NaN
# 10101002051 2004 1 Gram                                              NaN
# ...                                                                  ...
# 31202086364 2004 1 Kg                                                NaN
#                    Millilitre                                        NaN
#                    Piece                                             NaN
# 31202086374 2004 1 Kg                                                NaN
#                    Piece                                             NaN
#
# i                              Yoghurt  nan
# j           t    m u
# 10101002025 2004 1 Gram            NaN  NaN
#                    Kg              NaN  NaN
#                    Millilitre      NaN  NaN
#                    Piece           NaN  NaN
# 10101002051 2004 1 Gram            NaN  NaN
# ...                                ...  ...
# 31202086364 2004 1 Kg              NaN  NaN
#                    Millilitre      NaN  NaN
#                    Piece           NaN  NaN
# 31202086374 2004 1 Kg              NaN  NaN
#                    Piece           NaN  NaN
#
# [35977 rows x 129 columns]

# %% [markdown]
# Now that we have our consumption, we use the lecture code for the first step of estimation which is the "reduced form" linear regression. Before we are able to get our estimation of demand, we have to complete two steps:
#
# the first step
# involves estimating the &ldquo;reduced form&rdquo; linear regression
# $$
# y_{it}^j = {a}_{it} + \delta_i'{z}^j_t + \epsilon_{it}^j.
# $$

# %%
import sys
import cfe

y = np.log(x)
y
result = cfe.Result(y=y,z=z)
# Out:
# Missing dependencies for OracleDemands.

# %%
result.get_reduced_form()

# %% [markdown]
# Now we can see the estimated coefficient $\delta$ which reflects demand broken down by household characteristic.

# %%
result.delta.to_dataframe().unstack('k')
# Out:
#                                               delta                      \
# k                                             M 0-3     M 4-8    M 9-13
# i
# Avocado                                   -0.027469  0.036233 -0.003036
# Banana                                    -0.094776 -0.079738  0.054585
# Bean, brown                                0.033756  0.058986  0.062206
# Bean, white                                0.088998  0.050373  0.097664
# Beef                                      -0.098905  0.033595  0.060964
# Biscuits                                  -0.224607 -0.173919  0.092814
# Bread                                     -0.065294 -0.004541  0.059943
# Buns, scones                               0.045246  0.120182  0.113218
# Cabbage                                    0.014356  0.015227  0.079775
# Cassava tubers                             0.027358  0.048204  0.101075
# Chicken                                   -0.109181  0.007102  0.016048
# Chinese cabbage                            0.103933 -0.009215  0.075137
# Chips (vendor)                            -0.054027 -0.069796  0.035470
# Citrus, naartje, orange, etc.              0.005910 -0.110700  0.039455
# Cooking oil                               -0.099341 -0.079330  0.009946
# Dried fish                                -0.008991  0.006457  0.023662
# Eggs                                      -0.056172 -0.002189  0.055644
# Freezes (flavoured ice)                    0.126634  0.058527 -0.054907
# Fresh fish                                -0.121088 -0.049693 -0.031192
# Fresh milk                                -0.073576 -0.040439  0.057022
# Goat                                      -0.007920 -0.012172  0.109584
# Green maize                               -0.058496  0.010045  0.122148
# Groundnut                                 -0.028979 -0.001292  0.052138
# Groundnut flour                           -0.048324 -0.047073 -0.018861
# Irish potato                              -0.091835 -0.061779  0.038687
# Maize - boiled or roasted                 -0.041780  0.024351  0.097697
# Maize ufa mgaiwa (normal flour)            0.064310  0.112515  0.041167
# Maize ufa refined (fine flour)             0.018110  0.063524  0.142145
# Mandazi, doughnut (vendor)                 0.046214  0.009386  0.062543
# Meat (vendor)                             -0.004185  0.053168 -0.023871
# Meat eaten at restaurant                  -0.280654 -0.132582  0.000111
# Nkwani                                     0.031160  0.033066  0.047762
# Cooking oil                                0.284829  0.038245
# Dried fish                                 0.215636  0.056120
# Eggs                                       0.191382  0.139433
# Freezes (flavoured ice)                    0.195377  0.017806
# Fresh fish                                 0.345730  0.187551
# Fresh milk                                 0.217244  0.123476
# Goat                                       0.142300  0.135484
# Green maize                                0.161599  0.246544
# Groundnut                                  0.288612  0.195505
# Groundnut flour                            0.234289  0.258158
# Irish potato                               0.303212  0.095300
# Maize - boiled or roasted                  0.053344 -0.283684
# Maize ufa mgaiwa (normal flour)            0.104450  0.087280
# Maize ufa refined (fine flour)             0.129706  0.183128
# Mandazi, doughnut (vendor)                 0.129850  0.086360
# Meat (vendor)                             -0.061259  0.069284
# Meat eaten at restaurant                   0.276618 -0.116310
# Nkwani                                     0.145153  0.171931
# Okra / Therere                             0.105066  0.177010
# Onion                                      0.248710  0.161497
# Orange sweet potato                        0.156851  0.232720
# Pork                                       0.163814  0.103889
# Powdered milk                              0.273799  0.279443
# Rice                                       0.252772  0.183644
# Salt                                       0.163741  0.130213
# Samosa (vendor)                            0.322029  0.041109
# Soft drinks (coca cola, fanta)             0.107256 -0.112726
# Sugar                                      0.224773  0.162878
# Sugar cane                                 0.118298  0.075930
# Sweets, candy, chocolates                  0.463944  0.240703
# Tanaposi rape                              0.216115  0.208180
# Tea                                        0.174736  0.061600
# Tomato                                     0.278686  0.101662
# White sweet potato                         0.113096  0.142405
# Yeast, baking powder, bicarbonate of soda  0.361535  0.258369

# %% [markdown]
# We also estimate the good-time constants $a_{it}$ (this captures the effects of prices) by indexing 'i' which gives us the same estimation by time. In our case this is the years 2004 and 2010.

# %%
result.a.to_dataframe().unstack('i')
# Out:
#                a                                                        \
# i        Avocado    Banana Bean, brown Bean, white      Beef  Biscuits
# t    m
# 2004 1  2.732589  2.553386    3.563498    3.480738  4.906085  2.736930
# 2010 1  3.709544  3.873656    4.573519    4.511708  5.846323  3.824394
#
#                                                         ...                  \
# i          Bread Buns, scones   Cabbage Cassava tubers  ... Samosa (vendor)
# t    m                                                  ...
# 2004 1  4.330692     3.272087  2.821576       2.735024  ...        2.692764
# 2010 1  5.089198     4.234627  3.772250       3.782887  ...        3.680945
#
#                                                             \
# i      Soft drinks (coca cola, fanta)     Sugar Sugar cane
# t    m
# 2004 1                       4.026075  3.647259   2.475238
# 2010 1                       4.758748  4.549718   3.376966
#
#                                                                     \
# i      Sweets, candy, chocolates Tanaposi rape       Tea    Tomato
# t    m
# 2004 1                  1.879936      2.486638  2.237929  3.439653
# 2010 1                  3.224241      3.538246  2.994732  4.361938
#
#
# i      White sweet potato Yeast, baking powder, bicarbonate of soda
# t    m
# 2004 1           2.985221                                  1.016818
# 2010 1           4.048783                                  2.198148
#
# [2 rows x 49 columns]

# %% [markdown]
# Now we can continue with the second step. This is pulled from lecture code, using Singular Value Decomposition to find
# the rank one matrix that best approximates the residuals $e_{it}^j$.
# This can be interpreted as
# $$
#     -\beta_i\log\lambda^j_t,
# $$
# where the $\log\lambda^j_t$ is the log of the marginal utility of
# expenditures (MUE) for household $j$ at time $t$, and where $\beta_i$ are
# the corresponding &ldquo;Frisch elasticities&rdquo; that tell us how much
# demand changes as the MUE falls.
#
# We can run the one line of code to produce our estimates.

# %%
result.get_beta(as_df=True)
# Out:
# i
# Avocado                                      0.383249
# Banana                                       0.598940
# Bean, brown                                  0.192255
# Bean, white                                  0.232248
# Beef                                         0.365007
# Biscuits                                     0.816535
# Bread                                        0.360046
# Buns, scones                                 0.303703
# Cabbage                                      0.259849
# Cassava tubers                               0.286150
# Chicken                                      0.276638
# Chinese cabbage                              0.313419
# Chips (vendor)                               0.352606
# Citrus, naartje, orange, etc.                0.648388
# Cooking oil                                  0.591433
# Dried fish                                   0.369809
# Eggs                                         0.357952
# Freezes (flavoured ice)                      0.561462
# Fresh fish                                   0.630474
# Fresh milk                                   0.508618
# Goat                                         0.318212
# Green maize                                  0.273208
# Groundnut                                    0.459879
# Groundnut flour                              0.374055
# Irish potato                                 0.602801
# Maize - boiled or roasted                    0.314049
# Maize ufa mgaiwa (normal flour)              0.069368
# Maize ufa refined (fine flour)               0.115929
# Mandazi, doughnut (vendor)                   0.320827
# Meat (vendor)                                0.461454
# Meat eaten at restaurant                     0.782205
# Nkwani                                       0.176435
# Okra / Therere                               0.349072
# Onion                                        0.527057
# Orange sweet potato                          0.262067
# Pork                                         0.462047
# Powdered milk                                0.752334
# Rice                                         0.385456
# Salt                                         0.267673
# Samosa (vendor)                              0.650468
# Soft drinks (coca cola, fanta)               0.461191
# Sugar                                        0.232122
# Sugar cane                                   0.320151
# Sweets, candy, chocolates                    0.812745
# Tanaposi rape                                0.322396
# Tea                                          0.354066
# Tomato                                       0.587603
# White sweet potato                           0.215024
# Yeast, baking powder, bicarbonate of soda    0.430307
# Name: beta, dtype: float64

# %%
result.get_alpha(as_df = True)
# Out:
# i
# Avocado                                      2.732589
# Banana                                       2.553386
# Bean, brown                                  3.563498
# Bean, white                                  3.480738
# Beef                                         4.906085
# Biscuits                                     2.736930
# Bread                                        4.330692
# Buns, scones                                 3.272087
# Cabbage                                      2.821576
# Cassava tubers                               2.735024
# Chicken                                      5.382624
# Chinese cabbage                              2.325482
# Chips (vendor)                               3.575587
# Citrus, naartje, orange, etc.                2.329459
# Cooking oil                                  3.783886
# Dried fish                                   3.677535
# Eggs                                         3.874567
# Freezes (flavoured ice)                      1.836321
# Fresh fish                                   3.946580
# Fresh milk                                   3.970179
# Goat                                         4.455639
# Green maize                                  2.986889
# Groundnut                                    2.954719
# Groundnut flour                              2.387572
# Irish potato                                 3.484625
# Maize - boiled or roasted                    2.621591
# Maize ufa mgaiwa (normal flour)              4.513915
# Maize ufa refined (fine flour)               4.705971
# Mandazi, doughnut (vendor)                   2.603362
# Meat (vendor)                                3.466157
# Meat eaten at restaurant                     4.142331
# Nkwani                                       2.373014
# Okra / Therere                               2.184899
# Onion                                        2.340888
# Orange sweet potato                          2.913863
# Pork                                         4.290264
# Powdered milk                                4.057913
# Rice                                         3.952438
# Salt                                         2.203469
# Samosa (vendor)                              2.692764
# Soft drinks (coca cola, fanta)               4.026075
# Sugar                                        3.647259
# Sugar cane                                   2.475238
# Sweets, candy, chocolates                    1.879936
# Tanaposi rape                                2.486638
# Tea                                          2.237929
# Tomato                                       3.439653
# White sweet potato                           2.985221
# Yeast, baking powder, bicarbonate of soda    1.016818
# Name: alpha, dtype: float64

# %% [markdown]
# Now that we have our estimates, we can run an assessment of fit to compare our total expenditures by the model estimate with the actual total expenditures.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.cm as cm

xbar = np.exp(result.y).sum(['m','i']).to_dataframe('xbar').replace(0,np.nan).squeeze()
xhat = result.get_predicted_expenditures().sum(['m','i']).to_dataframe('xhat').replace(0,np.nan).squeeze()

# Make dataframe of actual & predicted
df = pd.DataFrame({'Actual':np.log(xbar),'Predicted':np.log(xhat)})

df.plot.scatter(x='Predicted',y='Actual')

# Add 45 degree line
v = plt.axis()
vmin = np.max([v[0],v[2]])
vmax = np.max([v[1],v[3]])
plt.plot([vmin,vmax],[vmin,vmax])

# %% [markdown]
# To save the result we run the follwing code.

# %%
result.to_dataset('icrisat.ds')
# Out:
# <xarray.Dataset>
# Dimensions:           (j: 23551, i: 49, k: 14, t: 2, m: 1, kp: 14)
# Coordinates:
#   * j                 (j) int64 10101002025 10101002051 ... 315556140434
#   * t                 (t) int64 2004 2010
#   * m                 (m) int64 1
#   * i                 (i) object 'Avocado' ... 'Yeast, baking powder, bicarbo...
#   * k                 (k) <U7 'M 0-3' 'M 4-8' 'M 9-13' ... 'F 31-50' 'F 51+'
#   * kp                (kp) <U7 'M 0-3' 'M 4-8' 'M 9-13' ... 'F 31-50' 'F 51+'
# Data variables: (12/20)
#     alpha             (i) float64 2.733 2.553 3.563 3.481 ... 3.44 2.985 1.017
#     beta              (i) float64 0.3832 0.5989 0.1923 ... 0.5876 0.215 0.4303
#     delta             (k, i) float64 -0.02747 -0.09478 0.03376 ... 0.1424 0.2584
#     prices            object None
#     characteristics   (k, j, t, m) float64 1.0 nan 0.0 nan ... nan 0.0 nan 0.0
#     loglambdas        (j, t, m) float64 nan nan nan nan nan ... nan nan nan nan
#     ...                ...
#     se_beta           object None
#     se_alpha          (i) float64 0.04403 0.02459 0.01747 ... 0.02794 0.04379
#     se_a              (i, t, m) float64 0.04403 0.04426 0.02459 ... 0.04379 0.03
#     y                 (i, j, t, m) float64 nan nan nan nan ... nan nan nan nan
#     logp              object None
#     z                 (k, j, t, m) float64 1.0 nan 0.0 nan ... nan 0.0 nan 0.0

# %% [markdown]
# ## Deliverable [B] Nutritional Content of Different Foods
#
# For this deliverable, we will use a new dataset that has Malawian foods and their corresponding nutrient characterstics. We begin by installing any necessary packages and reading the nutrition table data given to us in class.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = data = pd.read_csv('./Nutrient_Table.csv')
data = data.iloc[1: , :]
data
# Out:
#          Code  Food Group Reference  \
# 1   MW01_0001     Staples       R06
# 2   MW01_0002     Staples       R07
# 3   MW01_0003     Staples       R44
# 4   MW01_0004     Staples         2
# 5   MW01_0005     Staples         8
# ..        ...         ...       ...
# 60  MW04_0020   Vegetable        10
# 61  MW10_0011         NaN       NaN
# 62  MW04_0036  Vegetables       NaN
# 63  MW01_0066     Staples       NaN
# 64        NaN         NaN       NaN
#
#                                        Food Item Name  Mois Energy Energy.1  \
# 1   African cake, (Chikondamoyo/Chigumu cha nthoch...    49    215      911
# 2                        Banana fritters, (Zitumbuwa)  54.8    189      800
# 3   Bread, wheat, brown, homemade (Buledi wa bulaw...  11.2    362     1531
# 4     Bread, wheat, white, commercial,(Buledi woyera)  35.6    256     1086
# 5       Bread, wheat, white, homemade,(Buledi woyera)  37.2    270     1141
# ..                                                ...   ...    ...      ...
# 60                                      Tanaposi rape  89.7     37      158
# 61                                                Tea   100     33      138
# 62                                             Tomato  94.5     26      109
# 63                                 White sweet potato    76     97      411
# 64          Yeast, baking powder, bicarbonate of soda   NaN    NaN      NaN
#
#        N   Prot  Fat  ... Niac Vit B6 Folate Vit B12 Panto Biot Vit C Vit D  \
# 1   0.91    5.7    3  ...  0.8  0.292     15     0.1   NaN  NaN     4   NaN
# 2   0.51    3.2  2.5  ...  0.8  0.356     12     NaN   NaN  NaN     7     0
# 3   1.72  10. 7  6.2  ...  1.9  0.181     56       0   0.1  1.1   NaN   NaN
# 4   1.36    8.5  1.5  ...  1.2  0.071     30       0  0.31  NaN   NaN   NaN
# 5   1.65   10.4  4.6  ...  1.5  0.059     29       0   NaN  NaN     0     0
# ..   ...    ...  ...  ...  ...    ...    ...     ...   ...  ...   ...   ...
# 60  0.24    1.5  0.3  ...  0.6  0.263    194       0   NaN  NaN    60   NaN
# 61   NaN      0    0  ...  NaN    NaN    NaN     NaN   NaN  NaN   NaN   NaN
# 62  0.14    0.9  0.2  ...  0.6   0.08     15       0  0.02    0    14     0
# 63  0.21    1.3  0.1  ...  0.7  0.092      8       0  0.51  6.1     9     0
# 64   NaN    NaN  NaN  ...  NaN    NaN    NaN     NaN   NaN  NaN   NaN   NaN
#
#    Vit E Phytate
# 1   0.72     NaN
# 2    1.1     NaN
# 3   0.55     NaN
# 4    NaN     NaN
# 5      0     NaN
# ..   ...     ...
# 60  2.86     NaN
# 61   NaN     NaN
# 62  0.54     NaN
# 63  0.29     NaN
# 64   NaN     NaN
#
# [64 rows x 46 columns]

# %% [markdown]
# Next, we want to understand the nutritional significance of the foods consumed by our population. We will do so by taking note of the fiber intake by given the data in the nutrition table.
#
# We will first take note of the necessary recommended daily fiber intake for females and males.

# %%
fiber_dri_female = 25
fiber_dri_male = 38
fiber_female_meal = 25/3
fiber_male_meal = 38/3

# %% [markdown]
# Now we can use the nutrition data on fiber to understand what percentage of fiber females and males receive given traditional Malawian food staples.

# %%
data_copy = data.copy()
data_copy['Fiber'] = data_copy['Fiber'].astype(float)
female_fiber_percent = sum(data_copy['Fiber'] >= fiber_female_meal) / len(data_copy['Fiber'])
male_fiber_percent = sum(data_copy['Fiber'] >= fiber_male_meal) / len(data_copy['Fiber'])
print(female_fiber_percent)
print(male_fiber_percent)
# Out:
# 0.046875
# 0.015625

# %% [markdown]
# The outcomes is 4.6% and 1.5% for females and males, respectively.
#
# Next, we are interested in finding the healthy range of fat. To do so, we will calculate the lower and upper limit.

# %%
fat_dri_meal = [20/3, 35/3]

# %%
data_copy['Fat'] = data_copy['Fat'].astype(float)
data_copy['Fat.1'] = data_copy[['Fat']] > fat_dri_meal[1]
data_copy['Fat.2'] = data_copy[['Fat']] < fat_dri_meal[0]
fat_too_high = sum(data_copy['Fat.1']) / len(data_copy['Fat.1'])
fat_too_low = sum(data_copy['Fat.2']) / len(data_copy['Fat.2'])
print(fat_too_high)
print(fat_too_low)
# Out:
# 0.21875
# 0.703125

# %% [markdown]
# Our calculation tells us the the lower and upper limit of fat is 21% and 70%.
#
# Next we will produce a visualization graphing the fiber and fat contents of foods from the nutrient table to better understand the composition of foods consumed in Malawi.

# %%
plt.scatter(data['Fat'].astype(float).tolist(), data['Fiber'].astype(float).tolist())
plt.xlabel("Fat (g)")
plt.ylabel("Fiber (g)")
# Out:
# Text(0, 0.5, 'Fiber (g)')

# %% [markdown]
# ## Deliverable [B] Engel Curve
#
# We can now begin the deliverable creating visualizations with the Engel curve. We start by importing the necessary packages and following lecture code.

# %%
from cfe import demands
from cfe.demands import marshallian

def cobb_douglas_utility(alpha):
    """
    Define Cobb-Douglas utility function.
    """
    n = len(alpha)
    U = lambda c: demands.utility(c,alpha,[1]*n,[0]*n)

    return U

# Two good case:
alpha=[0.5,0.9] # Preference parameters

U = cobb_douglas_utility(alpha)

parms = {'alpha':[0.3,0.7], # Preference parameters
         'beta':[1,1], # Curvature parameters
         'phi':0}

# %% [markdown]
# We now use the prices to create the first basic visualization of the Engel curve that reflects a Cobb Douglass utility function.

# %%
# Demand for c_1 as a function of own price
D1 = lambda prices1,prices2=1,x=1: marshallian.demands(x,(prices1,prices2),parms)[0]

Prices = np.linspace(.5,5,20)

plt.plot([D1(prices1) for prices1 in Prices],Prices)
plt.xlabel('$Good 1$')
plt.ylabel('$Good 2$')

plt.show()

# %% [markdown]
# We can now add our goods relative to price and graph them.

# %%
from cfe.demands import marshallian
import numpy as np
import matplotlib.pyplot as plt

# Demand for c_1 as a function of own price
E1 = lambda x,price1=1,price2=1: marshallian.demands(x,(price1,price2),parms)

X = np.linspace(.1,10,20)

plt.plot(X,[E1(x)[0] for x in X],X,[E1(x)[1] for x in X])
plt.xlabel('$x$')
plt.ylabel('Consumptions')
plt.legend(('$Good1$','$Good2$'))
plt.title('Engel Curves')

plt.show()

# %% [markdown]
# ## Deliverable [C] - Counterfactual experiments
#
# ### Doubling expenditures
#
# We are next going to compute demand assuming expenditure values double. By doing so by simply multiplyinng our expenditure dataframe by 2.

# %%
x2 = x.iloc[:,:]*2
x2
# Out:
# i                    Apple  Avocado  Banana  Bean, brown  Bean, white    Beef  \
# j            t    m
# 10101002025  2004 1    NaN     20.0     NaN          NaN          NaN   320.0
# 10101002051  2004 1    NaN      NaN     NaN          NaN          NaN     NaN
# 10101002072  2004 1    NaN     10.0    10.0          NaN          NaN     NaN
# 10101002079  2004 1    NaN     32.0   120.0          NaN          NaN   120.0
# 10101002095  2004 1    NaN      NaN     NaN          NaN          NaN     NaN
# ...                    ...      ...     ...          ...          ...     ...
# 315556140342 2010 1    NaN      NaN     NaN        320.0          NaN     NaN
# 315556140365 2010 1    NaN      NaN   100.0          NaN          NaN     NaN
# 315556140388 2010 1    NaN      NaN     NaN          NaN          NaN     NaN
# 315556140411 2010 1    NaN      NaN     NaN          NaN        450.0     NaN
# 315556140434 2010 1    NaN      NaN   200.0        340.0          NaN  1000.0
#
# i                    Biscuits  Bottled water  Bottled/ canned beer  Bread  \
# j            t    m
# 10101002025  2004 1       NaN            NaN                   NaN    NaN
# 10101002051  2004 1       NaN            NaN                   NaN    NaN
# 10101002072  2004 1       NaN            NaN                   NaN    NaN
# 10101002079  2004 1       NaN            NaN                   NaN    NaN
# 10101002095  2004 1       NaN            NaN                   NaN    NaN
# ...                       ...            ...                   ...    ...
# 315556140342 2010 1       NaN            NaN                   NaN  520.0
# 315556140365 2010 1       NaN            NaN                   NaN    NaN
# 315556140388 2010 1       NaN            NaN                   NaN    NaN
# 315556140411 2010 1       NaN            NaN                   NaN    NaN
# 315556140434 2010 1       NaN            NaN                   NaN  260.0
#
# i                    ...  Tomato  Tomato sauce (bottle)  \
# j            t    m  ...
# 10101002025  2004 1  ...    10.0                    NaN
# 10101002051  2004 1  ...    10.0                    NaN
# 10101002072  2004 1  ...     NaN                    NaN
# 10101002079  2004 1  ...    20.0                    NaN
# 10101002095  2004 1  ...     NaN                    NaN
# ...                  ...     ...                    ...
# 315556140342 2010 1  ...   300.0                    NaN
# 315556140365 2010 1  ...   160.0                    NaN
# 315556140388 2010 1  ...    80.0                    NaN
# 315556140411 2010 1  ...   200.0                    NaN
# 315556140434 2010 1  ...   200.0                    NaN
#
# i                    Traditional beer (masase)  Wheat flour  \
# j            t    m
# 10101002025  2004 1                        NaN          NaN
# 10101002051  2004 1                        NaN          NaN
# 10101002072  2004 1                        NaN          NaN
# 10101002079  2004 1                        NaN          NaN
# 10101002095  2004 1                        NaN          NaN
# ...                                        ...          ...
# 315556140342 2010 1                        NaN          NaN
# 315556140365 2010 1                        NaN          NaN
# 315556140388 2010 1                        NaN          NaN
# 315556140411 2010 1                        NaN          NaN
# 315556140434 2010 1                        NaN          NaN
#
# i                    White sweet potato  Wild fruit (masau, mlambe, etc.)  \
# j            t    m
# 10101002025  2004 1                 NaN                               NaN
# 10101002051  2004 1                 NaN                               NaN
# 10101002072  2004 1                 NaN                               NaN
# 10101002079  2004 1                 NaN                               NaN
# 10101002095  2004 1                 NaN                               NaN
# ...                                 ...                               ...
# 315556140342 2010 1               400.0                               NaN
# 315556140365 2010 1               200.0                               NaN
# 315556140388 2010 1               100.0                               NaN
# 315556140411 2010 1               400.0                               NaN
# 315556140434 2010 1                 NaN                               NaN
#
# i                    Wine or commercial liquor  \
# j            t    m
# 10101002025  2004 1                        NaN
# 10101002051  2004 1                        NaN
# 10101002072  2004 1                        NaN
# 10101002079  2004 1                        NaN
# 10101002095  2004 1                        NaN
# ...                                        ...
# 315556140342 2010 1                        NaN
# 315556140365 2010 1                        NaN
# 315556140388 2010 1                        NaN
# 315556140411 2010 1                        NaN
# 315556140434 2010 1                        NaN
#
# i                    Yeast, baking powder, bicarbonate of soda  Yoghurt  nan
# j            t    m
# 10101002025  2004 1                                        8.0      NaN  NaN
# 10101002051  2004 1                                        NaN      NaN  NaN
# 10101002072  2004 1                                        6.0      NaN  NaN
# 10101002079  2004 1                                        4.0      NaN  NaN
# 10101002095  2004 1                                        6.0      NaN  NaN
# ...                                                        ...      ...  ...
# 315556140342 2010 1                                        NaN      NaN  NaN
# 315556140365 2010 1                                        NaN      NaN  NaN
# 315556140388 2010 1                                        NaN      NaN  NaN
# 315556140411 2010 1                                        NaN      NaN  NaN
# 315556140434 2010 1                                        NaN      NaN  NaN
#
# [23551 rows x 129 columns]

# %% [markdown]
# We now repeat the same process as before to create estimations and the final assessment of fit test.

# %%
# Get HH characteristics...
z2 = get_clean_sheet(InputFiles['HH Characteristics'][0],
                    sheet=InputFiles['HH Characteristics'][1])

if 'm' not in z2.columns:
    z2['m'] = 1

z2 = z2.set_index(['j','t','m'])
z2.columns.name = 'k'

z2 = z2.apply(lambda x2: pd.to_numeric(x2,errors='coerce'))

z2
# Out:
# Key available for students@eep153.iam.gserviceaccount.com.
# k                    M 0-3  M 4-8  M 9-13  M 14-18  M 19-30  M 31-50  M 51+  \
# j            t    m
# 10101002025  2004 1      1      0       1        1        0        1      0
# 10101002051  2004 1      0      0       0        0        1        0      0
# 10101002072  2004 1      1      1       0        1        0        1      0
# 10101002079  2004 1      0      1       0        0        0        1      0
# 10101002095  2004 1      0      0       2        0        1        0      0
# ...                    ...    ...     ...      ...      ...      ...    ...
# 315556140342 2010 1      1      0       0        0        1        0      0
# 315556140365 2010 1      0      0       0        0        0        1      0
# 315556140388 2010 1      0      0       0        0        1        0      0
# 315556140411 2010 1      1      0       0        0        2        0      0
# 315556140434 2010 1      0      0       0        1        0        1      0
#
# k                    F 0-3  F 4-8  F 9-13  F 14-18  F 19-30  F 31-50  F 51+
# j            t    m
# 10101002025  2004 1      1      1       0        0        0        1      0
# 10101002051  2004 1      1      0       0        1        0        0      0
# 10101002072  2004 1      1      0       0        0        1        0      0
# 10101002079  2004 1      2      1       0        0        0        1      0
# 10101002095  2004 1      0      2       0        0        1        0      0
# ...                    ...    ...     ...      ...      ...      ...    ...
# 315556140342 2010 1      0      0       0        0        1        0      0
# 315556140365 2010 1      0      0       0        0        0        1      0
# 315556140388 2010 1      0      0       0        1        0        0      0
# 315556140411 2010 1      1      0       0        0        1        0      0
# 315556140434 2010 1      0      0       2        0        2        1      0
#
# [23551 rows x 14 columns]

# %%
q2 = get_clean_sheet(InputFiles['malawi_consumption'][0],
                    sheet=InputFiles['malawi_consumption'][1])

if 'm' not in q2.columns:
    q2['m'] = 1

q2 = q2.set_index(['j','t','m','u'])
q2.columns.name = 'i'

q2 = q2.apply(lambda x2: pd.to_numeric(x2,errors='coerce'))
q2 = q2.replace(0,np.nan)

q2
# Out:
# Key available for students@eep153.iam.gserviceaccount.com.
# i                              Apple  Avocado  Banana  Bean, brown  \
# j           t    m u
# 10101002025 2004 1 Gram          NaN      NaN     NaN          NaN
#                    Kg            NaN      NaN     NaN          NaN
#                    Millilitre    NaN      NaN     NaN          NaN
#                    Piece         NaN      2.0     NaN          NaN
# 10101002051 2004 1 Gram          NaN      NaN     NaN          NaN
# ...                              ...      ...     ...          ...
# 31202086364 2004 1 Kg            NaN      NaN     NaN          NaN
#                    Millilitre    NaN      NaN     NaN          NaN
#                    Piece         NaN      NaN     NaN          NaN
# 31202086374 2004 1 Kg            NaN      NaN     NaN          NaN
#                    Piece         NaN      NaN     NaN          NaN
#
# i                              Bean, white  Beef  Biscuits  Bottled water  \
# j           t    m u
# 10101002025 2004 1 Gram                NaN   NaN       NaN            NaN
#                    Kg                  NaN   2.0       NaN            NaN
#                    Millilitre          NaN   NaN       NaN            NaN
#                    Piece               NaN   NaN       NaN            NaN
# 10101002051 2004 1 Gram                NaN   NaN       NaN            NaN
# ...                                    ...   ...       ...            ...
# 31202086364 2004 1 Kg                  NaN   NaN       NaN            NaN
#                    Millilitre          NaN   NaN       NaN            NaN
#                    Piece               NaN   NaN       NaN            NaN
# 31202086374 2004 1 Kg                  NaN   NaN       NaN            NaN
#                    Piece               NaN   NaN       NaN            NaN
#
# i                              Bottled/ canned beer  Bread  ...  Tomato  \
# j           t    m u                                        ...
# 10101002025 2004 1 Gram                         NaN    NaN  ...     NaN
#                    Kg                           NaN    NaN  ...     NaN
#                    Millilitre                   NaN    NaN  ...     NaN
#                    Piece                        NaN    NaN  ...     5.0
# 10101002051 2004 1 Gram                         NaN    NaN  ...     NaN
# ...                                             ...    ...  ...     ...
# 31202086364 2004 1 Kg                           NaN    NaN  ...     NaN
#                    Millilitre                   NaN    NaN  ...     NaN
#                    Piece                        NaN    NaN  ...    15.0
# 31202086374 2004 1 Kg                           NaN    NaN  ...     NaN
#                    Piece                        NaN    NaN  ...     7.0
#
# i                              Tomato sauce (bottle)  \
# j           t    m u
# 10101002025 2004 1 Gram                          NaN
#                    Kg                            NaN
#                    Millilitre                    NaN
#                    Piece                         NaN
# 10101002051 2004 1 Gram                          NaN
# ...                                              ...
# 31202086364 2004 1 Kg                            NaN
#                    Millilitre                    NaN
#                    Piece                         NaN
# 31202086374 2004 1 Kg                            NaN
#                    Piece                         NaN
#
# i                              Traditional beer (masase)  Wheat flour  \
# j           t    m u
# 10101002025 2004 1 Gram                              NaN          NaN
#                    Kg                                NaN          NaN
#                    Millilitre                        NaN          NaN
#                    Piece                             NaN          NaN
# 10101002051 2004 1 Gram                              NaN          NaN
# ...                                                  ...          ...
# 31202086364 2004 1 Kg                                NaN          NaN
#                    Millilitre                        NaN          NaN
#                    Piece                             NaN          NaN
# 31202086374 2004 1 Kg                                NaN          NaN
#                    Piece                             NaN          NaN
#
# i                              White sweet potato  \
# j           t    m u
# 10101002025 2004 1 Gram                       NaN
#                    Kg                         NaN
#                    Millilitre                 NaN
#                    Piece                      NaN
# 10101002051 2004 1 Gram                       NaN
# ...                                           ...
# 31202086364 2004 1 Kg                         NaN
#                    Millilitre                 NaN
#                    Piece                     15.0
# 31202086374 2004 1 Kg                         NaN
#                    Piece                      NaN
#
# i                              Wild fruit (masau, mlambe, etc.)  \
# j           t    m u
# 10101002025 2004 1 Gram                                     NaN
#                    Kg                                       NaN
#                    Millilitre                               NaN
#                    Piece                                    NaN
# 10101002051 2004 1 Gram                                     NaN
# ...                                                         ...
# 31202086364 2004 1 Kg                                       NaN
#                    Millilitre                               NaN
#                    Piece                                    NaN
# 31202086374 2004 1 Kg                                       NaN
#                    Piece                                    NaN
#
# i                              Wine or commercial liquor  \
# j           t    m u
# 10101002025 2004 1 Gram                              NaN
#                    Kg                                NaN
#                    Millilitre                        NaN
#                    Piece                             NaN
# 10101002051 2004 1 Gram                              NaN
# ...                                                  ...
# 31202086364 2004 1 Kg                                NaN
#                    Millilitre                        NaN
#                    Piece                             NaN
# 31202086374 2004 1 Kg                                NaN
#                    Piece                             NaN
#
# i                              Yeast, baking powder, bicarbonate of soda  \
# j           t    m u
# 10101002025 2004 1 Gram                                              NaN
#                    Kg                                                NaN
#                    Millilitre                                        NaN
#                    Piece                                             NaN
# 10101002051 2004 1 Gram                                              NaN
# ...                                                                  ...
# 31202086364 2004 1 Kg                                                NaN
#                    Millilitre                                        NaN
#                    Piece                                             NaN
# 31202086374 2004 1 Kg                                                NaN
#                    Piece                                             NaN
#
# i                              Yoghurt  nan
# j           t    m u
# 10101002025 2004 1 Gram            NaN  NaN
#                    Kg              NaN  NaN
#                    Millilitre      NaN  NaN
#                    Piece           NaN  NaN
# 10101002051 2004 1 Gram            NaN  NaN
# ...                                ...  ...
# 31202086364 2004 1 Kg              NaN  NaN
#                    Millilitre      NaN  NaN
#                    Piece           NaN  NaN
# 31202086374 2004 1 Kg              NaN  NaN
#                    Piece           NaN  NaN
#
# [35977 rows x 129 columns]

# %%
import sys
import cfe

y2 = np.log(x2)
y2
result2 = cfe.Result(y=y2,z=z2)

# %%
result2.get_reduced_form()

# %%
result2.delta.to_dataframe().unstack('k')
# Out:
#                                               delta                      \
# k                                             M 0-3     M 4-8    M 9-13
# i
# Avocado                                   -0.027469  0.036233 -0.003036
# Banana                                    -0.094776 -0.079738  0.054585
# Bean, brown                                0.033756  0.058986  0.062206
# Bean, white                                0.088998  0.050373  0.097664
# Beef                                      -0.098905  0.033595  0.060964
# Biscuits                                  -0.224607 -0.173919  0.092814
# Bread                                     -0.065294 -0.004541  0.059943
# Buns, scones                               0.045246  0.120182  0.113218
# Cabbage                                    0.014356  0.015227  0.079775
# Cassava tubers                             0.027358  0.048204  0.101075
# Chicken                                   -0.109181  0.007102  0.016048
# Chinese cabbage                            0.103933 -0.009215  0.075137
# Chips (vendor)                            -0.054027 -0.069796  0.035470
# Citrus, naartje, orange, etc.              0.005910 -0.110700  0.039455
# Cooking oil                               -0.099341 -0.079330  0.009946
# Dried fish                                -0.008991  0.006457  0.023662
# Eggs                                      -0.056172 -0.002189  0.055644
# Freezes (flavoured ice)                    0.126634  0.058527 -0.054907
# Fresh fish                                -0.121088 -0.049693 -0.031192
# Fresh milk                                -0.073576 -0.040439  0.057022
# Goat                                      -0.007920 -0.012172  0.109584
# Green maize                               -0.058496  0.010045  0.122148
# Groundnut                                 -0.028979 -0.001292  0.052138
# Groundnut flour                           -0.048324 -0.047073 -0.018861
# Irish potato                              -0.091835 -0.061779  0.038687
# Maize - boiled or roasted                 -0.041780  0.024351  0.097697
# Maize ufa mgaiwa (normal flour)            0.064310  0.112515  0.041167
# Maize ufa refined (fine flour)             0.018110  0.063524  0.142145
# Mandazi, doughnut (vendor)                 0.046214  0.009386  0.062543
# Meat (vendor)                             -0.004185  0.053168 -0.023871
# Meat eaten at restaurant                  -0.280654 -0.132582  0.000111
# Nkwani                                     0.031160  0.033066  0.047762
# Okra / Therere                             0.014872 -0.055624  0.051188
# Onion                                     -0.091255 -0.071492  0.024967
# Tanaposi rape                              0.126746  0.135164  0.170214
# Tea                                        0.048048  0.117211  0.189898
# Tomato                                     0.043258  0.173740  0.297261
# White sweet potato                         0.145766  0.143146  0.178093
# Yeast, baking powder, bicarbonate of soda -0.033866  0.127911  0.120521
#
#                                                                          \
# k                                             M 51+     F 0-3     F 4-8
# i
# Avocado                                    0.018908 -0.087403 -0.009585
# Banana                                     0.213016 -0.110090 -0.007929
# Bean, brown                                0.143387  0.013508  0.043258
# Bean, white                                0.199757  0.044022  0.022708
# Beef                                       0.180216 -0.074129  0.001774
# Biscuits                                  -0.037103 -0.185296 -0.050876
# Bread                                      0.155057 -0.091175  0.025823
# Buns, scones                               0.248430  0.073798  0.113291
# Cabbage                                    0.119748 -0.010438 -0.008238
# Cassava tubers                             0.160762  0.046434  0.072727
# Chicken                                   -0.058443 -0.089535 -0.017776
# Chinese cabbage                            0.038838 -0.024709 -0.005434
# Chips (vendor)                            -0.002261 -0.099542 -0.089744
# Citrus, naartje, orange, etc.              0.082161 -0.089849 -0.117571
# Cooking oil                                0.107237 -0.164351 -0.061832
# Dried fish                                 0.175061 -0.001012  0.052686
# Eggs                                       0.070593 -0.040586  0.013013
# Freezes (flavoured ice)                    0.144495 -0.034632 -0.064615
# Fresh fish                                 0.108556 -0.106362  0.011824
# Fresh milk                                 0.000937 -0.147667 -0.025760
# Goat                                       0.125221  0.038126  0.056856
# Green maize                                0.373337  0.016450  0.065964
# Groundnut                                  0.162785 -0.055533  0.033106
# Groundnut flour                            0.228307 -0.026465  0.049301
# Irish potato                               0.187292 -0.127194 -0.012169
# Maize - boiled or roasted                  0.103943 -0.130957  0.058817
# Maize ufa mgaiwa (normal flour)            0.090428  0.076530  0.083246
# Maize ufa refined (fine flour)             0.125894  0.008851  0.082149
# Mandazi, doughnut (vendor)                 0.113776  0.018463  0.078410
# Meat (vendor)                             -0.015240 -0.236163 -0.142558
# Meat eaten at restaurant                   0.064531 -0.526741 -0.020780
# Nkwani                                     0.143584 -0.001890  0.084364
# Okra / Therere                             0.055996 -0.031443  0.066062
# Onion                                      0.043194 -0.109088 -0.023884
# Orange sweet potato                        0.138380  0.181608 -0.005710
# Pork                                       0.327295 -0.031547  0.061076
# Powdered milk                              0.045279 -0.213692  0.100166
# Rice                                       0.128957 -0.032089  0.068104
# Salt                                       0.074158  0.026276  0.025132
# Samosa (vendor)                           -0.276632 -0.239811 -0.023209
# Soft drinks (coca cola, fanta)             0.197055 -0.123856 -0.015868
# Sugar                                      0.133182  0.035919  0.069334
# Sugar cane                                -0.035397  0.019663  0.015862
# Sweets, candy, chocolates                 -0.259711 -0.225276 -0.116079
# Tanaposi rape                              0.054216  0.030414  0.052227
# Tea                                        0.185355  0.008707  0.009815
# Tomato                                     0.009546 -0.093303 -0.024883
# White sweet potato                         0.198186  0.107016  0.071973
# Yeast, baking powder, bicarbonate of soda -0.100549 -0.054421 -0.015518
#
#                                                                          \
# k                                            F 9-13   F 14-18   F 19-30
# i
# Avocado                                    0.191842  0.054297  0.141149
# Banana                                     0.043536  0.084105  0.261624
# Freezes (flavoured ice)                    0.195377  0.017806
# Fresh fish                                 0.345730  0.187551
# Fresh milk                                 0.217244  0.123476
# Goat                                       0.142300  0.135484
# Green maize                                0.161599  0.246544
# Groundnut                                  0.288612  0.195505
# Groundnut flour                            0.234289  0.258158
# Irish potato                               0.303212  0.095300
# Maize - boiled or roasted                  0.053344 -0.283684
# Maize ufa mgaiwa (normal flour)            0.104450  0.087280
# Maize ufa refined (fine flour)             0.129706  0.183128
# Mandazi, doughnut (vendor)                 0.129850  0.086360
# Meat (vendor)                             -0.061259  0.069284
# Meat eaten at restaurant                   0.276618 -0.116310
# Nkwani                                     0.145153  0.171931
# Okra / Therere                             0.105066  0.177010
# Onion                                      0.248710  0.161497
# Orange sweet potato                        0.156851  0.232720
# Pork                                       0.163814  0.103889
# Powdered milk                              0.273799  0.279443
# Rice                                       0.252772  0.183644
# Salt                                       0.163741  0.130213
# Samosa (vendor)                            0.322029  0.041109
# Soft drinks (coca cola, fanta)             0.107256 -0.112726
# Sugar                                      0.224773  0.162878
# Sugar cane                                 0.118298  0.075930
# Sweets, candy, chocolates                  0.463944  0.240703
# Tanaposi rape                              0.216115  0.208180
# Tea                                        0.174736  0.061600
# Tomato                                     0.278686  0.101662
# White sweet potato                         0.113096  0.142405
# Yeast, baking powder, bicarbonate of soda  0.361535  0.258369

# %%
result2.a.to_dataframe().unstack('i')
# Out:
#                a                                                        \
# i        Avocado    Banana Bean, brown Bean, white      Beef  Biscuits
# t    m
# 2004 1  3.425736  3.246533    4.256645    4.173885  5.599232  3.430078
# 2010 1  4.402691  4.566804    5.266667    5.204855  6.539470  4.517541
#
#                                                         ...                  \
# i          Bread Buns, scones   Cabbage Cassava tubers  ... Samosa (vendor)
# t    m                                                  ...
# 2004 1  5.023839     3.965235  3.514723       3.428171  ...        3.385911
# 2010 1  5.782345     4.927774  4.465397       4.476034  ...        4.374092
#
#                                                             \
# i      Soft drinks (coca cola, fanta)     Sugar Sugar cane
# t    m
# 2004 1                       4.719222  4.340406   3.168386
# 2010 1                       5.451895  5.242865   4.070113
#
#                                                                     \
# i      Sweets, candy, chocolates Tanaposi rape       Tea    Tomato
# t    m
# 2004 1                  2.573083      3.179785  2.931077  4.132800
# 2010 1                  3.917388      4.231393  3.687879  5.055085
#
#
# i      White sweet potato Yeast, baking powder, bicarbonate of soda
# t    m
# 2004 1           3.678368                                  1.709965
# 2010 1           4.741930                                  2.891295
#
# [2 rows x 49 columns]

# %%
result2.get_beta(as_df=True)
# Out:
# i
# Avocado                                      0.383249
# Banana                                       0.598940
# Bean, brown                                  0.192255
# Bean, white                                  0.232248
# Beef                                         0.365007
# Biscuits                                     0.816535
# Bread                                        0.360046
# Buns, scones                                 0.303703
# Cabbage                                      0.259849
# Cassava tubers                               0.286150
# Chicken                                      0.276638
# Chinese cabbage                              0.313419
# Chips (vendor)                               0.352606
# Citrus, naartje, orange, etc.                0.648388
# Cooking oil                                  0.591433
# Dried fish                                   0.369809
# Eggs                                         0.357952
# Freezes (flavoured ice)                      0.561462
# Fresh fish                                   0.630474
# Fresh milk                                   0.508618
# Goat                                         0.318212
# Green maize                                  0.273208
# Groundnut                                    0.459879
# Groundnut flour                              0.374055
# Irish potato                                 0.602801
# Maize - boiled or roasted                    0.314049
# Maize ufa mgaiwa (normal flour)              0.069368
# Maize ufa refined (fine flour)               0.115929
# Mandazi, doughnut (vendor)                   0.320827
# Meat (vendor)                                0.461454
# Meat eaten at restaurant                     0.782205
# Nkwani                                       0.176435
# Okra / Therere                               0.349072
# Onion                                        0.527057
# Orange sweet potato                          0.262067
# Pork                                         0.462047
# Powdered milk                                0.752334
# Rice                                         0.385456
# Salt                                         0.267673
# Samosa (vendor)                              0.650468
# Soft drinks (coca cola, fanta)               0.461191
# Sugar                                        0.232122
# Sugar cane                                   0.320151
# Sweets, candy, chocolates                    0.812745
# Tanaposi rape                                0.322396
# Tea                                          0.354066
# Tomato                                       0.587603
# White sweet potato                           0.215024
# Yeast, baking powder, bicarbonate of soda    0.430307
# Name: beta, dtype: float64

# %%
result2.get_alpha(as_df = True)
# Out:
# i
# Avocado                                      3.425736
# Banana                                       3.246533
# Bean, brown                                  4.256645
# Bean, white                                  4.173885
# Beef                                         5.599232
# Biscuits                                     3.430078
# Bread                                        5.023839
# Buns, scones                                 3.965235
# Cabbage                                      3.514723
# Cassava tubers                               3.428171
# Chicken                                      6.075771
# Chinese cabbage                              3.018630
# Chips (vendor)                               4.268734
# Citrus, naartje, orange, etc.                3.022607
# Cooking oil                                  4.477033
# Dried fish                                   4.370683
# Eggs                                         4.567714
# Freezes (flavoured ice)                      2.529468
# Fresh fish                                   4.639727
# Fresh milk                                   4.663326
# Goat                                         5.148786
# Green maize                                  3.680036
# Groundnut                                    3.647866
# Groundnut flour                              3.080719
# Irish potato                                 4.177772
# Maize - boiled or roasted                    3.314738
# Maize ufa mgaiwa (normal flour)              5.207062
# Maize ufa refined (fine flour)               5.399118
# Mandazi, doughnut (vendor)                   3.296509
# Meat (vendor)                                4.159304
# Meat eaten at restaurant                     4.835479
# Nkwani                                       3.066161
# Okra / Therere                               2.878047
# Onion                                        3.034035
# Orange sweet potato                          3.607010
# Pork                                         4.983411
# Powdered milk                                4.751061
# Rice                                         4.645585
# Salt                                         2.896616
# Samosa (vendor)                              3.385911
# Soft drinks (coca cola, fanta)               4.719222
# Sugar                                        4.340406
# Sugar cane                                   3.168386
# Sweets, candy, chocolates                    2.573083
# Tanaposi rape                                3.179785
# Tea                                          2.931077
# Tomato                                       4.132800
# White sweet potato                           3.678368
# Yeast, baking powder, bicarbonate of soda    1.709965
# Name: alpha, dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.cm as cm

xbar = np.exp(result2.y).sum(['m','i']).to_dataframe('xbar').replace(0,np.nan).squeeze()
xhat = result2.get_predicted_expenditures().sum(['m','i']).to_dataframe('xhat').replace(0,np.nan).squeeze()

# Make dataframe of actual & predicted
df = pd.DataFrame({'Actual':np.log(xbar),'Predicted':np.log(xhat)})

df.plot.scatter(x='Predicted',y='Actual')

# Add 45 degree line
v = plt.axis()
vmin = np.max([v[0],v[2]])
vmax = np.max([v[1],v[3]])
plt.plot([vmin,vmax],[vmin,vmax])
